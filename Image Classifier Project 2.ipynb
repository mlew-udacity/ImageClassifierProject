# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='https://github.com/mlew-udacity/ImageClassifierProject/blob/main/assets/Flowers.png?raw=1' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from collections import OrderedDict
from matplotlib import pyplot as plt

import numpy as np
from PIL import Image

import json
import time

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'gdrive/MyDrive/flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
#Transforms for the training, validation, and testing sets
def load_data(data_dir='flowers'):
    train_dir = data_dir + '/train'
    valid_dir = data_dir + '/valid'
    test_dir = data_dir + '/test'

    train_transforms = transforms.Compose([transforms.RandomRotation(30),  #Rotate 30 degrees each way
                                           transforms.RandomResizedCrop(224), #Crop to 224 x 224 pixel
                                           transforms.RandomHorizontalFlip(), #Flip horizonally
                                           transforms.ToTensor(),  #Convert Tensor
                                           transforms.Normalize([0.485, 0.456, 0.406],  #Mean
                                                                [0.229, 0.224, 0.225])]) #Standard Dev

    test_transforms = transforms.Compose([transforms.Resize(255),
                                          transforms.CenterCrop(224),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406],
                                                               [0.229, 0.224, 0.225])])

    valid_transforms = transforms.Compose([transforms.Resize(255),
                                          transforms.CenterCrop(224),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406],
                                                               [0.229, 0.224, 0.225])])

    # Load the datasets with ImageFolder
    train_data = datasets.ImageFolder(train_dir, transform=train_transforms)
    test_data = datasets.ImageFolder(test_dir, transform=test_transforms)
    valid_data = datasets.ImageFolder(valid_dir, transform=valid_transforms)

    # Using the image datasets and the trainforms, define the dataloaders
    trainloader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)
    testloader = torch.utils.data.DataLoader(test_data, batch_size=32)
    validloader = torch.utils.data.DataLoader(valid_data, batch_size=32)

    return train_data, trainloader, testloader, validloader

train_data, trainloader, testloader, validloader=load_data(data_dir)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
#Build network

# Use GPU if it's available - otherwise use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load pre-trained model - vgg16
model = models.vgg16(weights=True)

#Classifer function to build layers attach to existing model eg VGG16
def classifier(model, inputs, hidden, outputs):
    for param in model.parameters():
        param.requires_grad = False

    #List of different operations and pass a tensor through sequentially
    classifier = nn.Sequential(OrderedDict([
                            ('fc1', nn.Linear(inputs, hidden)), #layer 1
                            ('relu1', nn.ReLU()),
                            ('dropout',nn.Dropout(0.5)),
                            ('fc2', nn.Linear(hidden, outputs)), #output size = 102
                            ('output', nn.LogSoftmax(dim=1))]))# For using NLLLoss()

    return classifier

# %%
#Build 1 layer model  - This is fit for purpose to prevent overfitting.
def build_model(model, inputs=25088, hidden=1096, outputs=102, lr=0.001):

    # Run Classifer function and attach to model
    model.classifier = classifier(model, inputs, hidden, outputs)

    # Define Loss - negative likelihood loss
    criterion = nn.NLLLoss()

    # Optimiser - get the parameters from model, set learning rate
    optimiser = optim.Adam(model.classifier.parameters(), lr)

    #move our model to device e.g. cuda or cpu
    model.to(device)
    return model, criterion, optimiser

model, criterion, optimiser= build_model(model, inputs=25088, hidden=1096, outputs=102)
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=1096, bias=True)
#     (relu1): ReLU()
#     (dropout): Dropout(p=0.5, inplace=False)
#     (fc2): Linear(in_features=1096, out_features=102, bias=True)
#     (output): LogSoftmax(dim=1)
#   )
# )

# %%
# Function to Train Network - Arguments include Epochs and validation step for when to run validation.
def train_network(epochs, validation_step):
    steps=0
    running_loss = 0

    for epoch in range(epochs):
        for images, labels in trainloader:
            steps += 1 #increment steps

            # Move input and label tensors to the default device
            images, labels = images.to(device), labels.to(device)
            optimiser.zero_grad() #zero out gradients
            output_logps = model.forward(images)             #Log probability from model with forward pass

            # Calculate loss and Increment
            loss = criterion(output_logps, labels)
            loss.backward() #backwards pass - calculate gradient
            optimiser.step() #Adjust parameters
            running_loss += loss.item()

           # Validation - For every Xth step - test networks accuracy and loss on validation data set.
            if steps % validation_step == 0:
                valid_loss = 0
                accuracy = 0
                model.eval() #turns off model inference mode - ie. turns off dropout so we can use network for make predictions
                with torch.no_grad(): #no grad turn off for validation

                    # Run Validation function to calculation valiation loss and accuracy
                    valid_loss, accuracy = validate_network(model, validloader, criterion)

                print(f"Epoch {epoch+1}/{epochs}.. "
                      f"Training loss: {running_loss/validation_step:.3f}.. " #average of training loss
                      f"Validation loss: {valid_loss/len(validloader):.3f}.. " # average loss - len(validloader) tells us how many batches we are getting
                      f"Validation accuracy: {(accuracy/len(validloader))*100:.2f}%") #average accuracy - summing up accuracy for each batch / total number of batches
                running_loss = 0 #set running loss back to 0
                model.train() #set model back into training mode

# %%
# Validation Function
def validate_network(model, validloader, criterion):
    valid_loss = 0
    accuracy = 0

    for images, labels in validloader:
        inputs, labels = inputs.to(device), labels.to(device)
        output_logps = model.forward(inputs)
        valid_loss += criterion(output_logps, labels).item()

        # Calculate accuracy
        probability = torch.exp(output_logps)
        top_p, top_class = probability.topk(1, dim=1) #top 1 of each row (along columns)
        equals = top_class == labels.view(*top_class.shape) #compares class to labels (reshapes labels tensor)
        accuracy += equals.type(torch.FloatTensor).mean()

    return valid_loss, accuracy

# %%
# Run function to train Network - set active session to True
active_session = True

while active_session:
    train_network(6, 5)
    active_session = False
# Out:
# Epoch 1/6.. Training loss: 5.976.. Validation loss: 6.110.. Validation accuracy: 7.40%
# Epoch 1/6.. Training loss: 5.757.. Validation loss: 4.504.. Validation accuracy: 16.17%
# Epoch 1/6.. Training loss: 4.209.. Validation loss: 3.722.. Validation accuracy: 21.11%
# Epoch 1/6.. Training loss: 4.191.. Validation loss: 3.606.. Validation accuracy: 24.71%
# Epoch 1/6.. Training loss: 4.045.. Validation loss: 3.392.. Validation accuracy: 30.41%
# Epoch 1/6.. Training loss: 3.909.. Validation loss: 3.264.. Validation accuracy: 29.69%
# Epoch 1/6.. Training loss: 3.594.. Validation loss: 3.028.. Validation accuracy: 33.89%
# Epoch 1/6.. Training loss: 3.476.. Validation loss: 2.857.. Validation accuracy: 36.19%
# Epoch 1/6.. Training loss: 3.397.. Validation loss: 2.651.. Validation accuracy: 39.41%
# Epoch 1/6.. Training loss: 3.714.. Validation loss: 2.490.. Validation accuracy: 45.23%
# Epoch 1/6.. Training loss: 3.216.. Validation loss: 2.372.. Validation accuracy: 47.24%
# Epoch 1/6.. Training loss: 2.933.. Validation loss: 2.311.. Validation accuracy: 43.75%
# Epoch 1/6.. Training loss: 3.117.. Validation loss: 2.169.. Validation accuracy: 47.54%
# Epoch 1/6.. Training loss: 2.509.. Validation loss: 2.070.. Validation accuracy: 50.25%
# Epoch 1/6.. Training loss: 2.889.. Validation loss: 1.974.. Validation accuracy: 51.67%
# Epoch 1/6.. Training loss: 2.639.. Validation loss: 2.012.. Validation accuracy: 51.68%
# Epoch 1/6.. Training loss: 2.905.. Validation loss: 1.991.. Validation accuracy: 51.40%
# Epoch 1/6.. Training loss: 2.709.. Validation loss: 1.867.. Validation accuracy: 54.02%
# Epoch 1/6.. Training loss: 2.805.. Validation loss: 1.785.. Validation accuracy: 56.54%
# Epoch 1/6.. Training loss: 2.542.. Validation loss: 1.745.. Validation accuracy: 54.77%
# Epoch 1/6.. Training loss: 2.746.. Validation loss: 1.599.. Validation accuracy: 60.31%
# Epoch 1/6.. Training loss: 2.667.. Validation loss: 1.494.. Validation accuracy: 62.74%
# Epoch 1/6.. Training loss: 2.568.. Validation loss: 1.502.. Validation accuracy: 62.38%
# Epoch 1/6.. Training loss: 2.286.. Validation loss: 1.526.. Validation accuracy: 60.42%
# Epoch 1/6.. Training loss: 2.566.. Validation loss: 1.410.. Validation accuracy: 61.26%
# Epoch 1/6.. Training loss: 2.373.. Validation loss: 1.326.. Validation accuracy: 63.70%
# Epoch 1/6.. Training loss: 2.610.. Validation loss: 1.363.. Validation accuracy: 64.20%
# Epoch 1/6.. Training loss: 2.419.. Validation loss: 1.309.. Validation accuracy: 66.64%
# Epoch 1/6.. Training loss: 2.154.. Validation loss: 1.255.. Validation accuracy: 66.28%
# Epoch 1/6.. Training loss: 2.428.. Validation loss: 1.251.. Validation accuracy: 65.64%
# Epoch 1/6.. Training loss: 2.191.. Validation loss: 1.241.. Validation accuracy: 66.72%
# Epoch 1/6.. Training loss: 2.465.. Validation loss: 1.206.. Validation accuracy: 68.44%
# Epoch 1/6.. Training loss: 2.681.. Validation loss: 1.143.. Validation accuracy: 71.54%
# Epoch 1/6.. Training loss: 2.332.. Validation loss: 1.132.. Validation accuracy: 73.32%
# Epoch 1/6.. Training loss: 2.114.. Validation loss: 1.112.. Validation accuracy: 72.60%
# Epoch 1/6.. Training loss: 2.274.. Validation loss: 1.053.. Validation accuracy: 73.01%
# Epoch 1/6.. Training loss: 1.836.. Validation loss: 1.037.. Validation accuracy: 72.80%
# Epoch 1/6.. Training loss: 2.149.. Validation loss: 1.023.. Validation accuracy: 73.69%
# Epoch 1/6.. Training loss: 1.902.. Validation loss: 1.114.. Validation accuracy: 67.96%
# Epoch 1/6.. Training loss: 2.431.. Validation loss: 1.102.. Validation accuracy: 71.22%
# Epoch 1/6.. Training loss: 2.256.. Validation loss: 1.051.. Validation accuracy: 73.09%
# Epoch 2/6.. Training loss: 1.913.. Validation loss: 1.014.. Validation accuracy: 73.93%
# Epoch 2/6.. Training loss: 1.999.. Validation loss: 0.968.. Validation accuracy: 75.37%
# Epoch 2/6.. Training loss: 1.683.. Validation loss: 1.022.. Validation accuracy: 72.94%
# Epoch 2/6.. Training loss: 1.959.. Validation loss: 1.006.. Validation accuracy: 73.38%
# Epoch 2/6.. Training loss: 1.614.. Validation loss: 1.027.. Validation accuracy: 72.54%
# Epoch 2/6.. Training loss: 2.134.. Validation loss: 1.055.. Validation accuracy: 70.43%
# Epoch 2/6.. Training loss: 2.065.. Validation loss: 0.992.. Validation accuracy: 73.00%
# Epoch 2/6.. Training loss: 1.859.. Validation loss: 0.951.. Validation accuracy: 75.65%
# Epoch 2/6.. Training loss: 1.758.. Validation loss: 0.973.. Validation accuracy: 74.19%
# Epoch 2/6.. Training loss: 1.934.. Validation loss: 0.952.. Validation accuracy: 74.12%
# Epoch 2/6.. Training loss: 1.897.. Validation loss: 0.901.. Validation accuracy: 75.39%
# Epoch 2/6.. Training loss: 2.128.. Validation loss: 0.949.. Validation accuracy: 73.40%
# Epoch 2/6.. Training loss: 1.732.. Validation loss: 0.920.. Validation accuracy: 74.89%
# Epoch 2/6.. Training loss: 1.958.. Validation loss: 0.903.. Validation accuracy: 76.88%
# Epoch 2/6.. Training loss: 1.681.. Validation loss: 0.896.. Validation accuracy: 78.15%
# Epoch 2/6.. Training loss: 2.118.. Validation loss: 0.864.. Validation accuracy: 77.67%
# Epoch 2/6.. Training loss: 1.828.. Validation loss: 0.858.. Validation accuracy: 77.67%
# Epoch 2/6.. Training loss: 1.991.. Validation loss: 0.842.. Validation accuracy: 76.40%
# Epoch 2/6.. Training loss: 1.879.. Validation loss: 0.866.. Validation accuracy: 75.15%
# Epoch 2/6.. Training loss: 2.025.. Validation loss: 0.838.. Validation accuracy: 75.27%
# Epoch 2/6.. Training loss: 1.633.. Validation loss: 0.859.. Validation accuracy: 75.99%
# Epoch 2/6.. Training loss: 1.791.. Validation loss: 0.870.. Validation accuracy: 76.14%
# Epoch 2/6.. Training loss: 2.134.. Validation loss: 0.876.. Validation accuracy: 76.19%
# Epoch 2/6.. Training loss: 1.919.. Validation loss: 0.843.. Validation accuracy: 77.36%
# Epoch 2/6.. Training loss: 2.085.. Validation loss: 0.832.. Validation accuracy: 77.07%
# Epoch 2/6.. Training loss: 1.873.. Validation loss: 0.837.. Validation accuracy: 78.54%
# Epoch 2/6.. Training loss: 1.837.. Validation loss: 0.880.. Validation accuracy: 77.34%
# Epoch 2/6.. Training loss: 1.952.. Validation loss: 0.885.. Validation accuracy: 75.68%
# Epoch 2/6.. Training loss: 1.554.. Validation loss: 0.866.. Validation accuracy: 76.16%
# Epoch 2/6.. Training loss: 1.990.. Validation loss: 0.839.. Validation accuracy: 76.88%
# Epoch 2/6.. Training loss: 1.911.. Validation loss: 0.815.. Validation accuracy: 78.93%
# Epoch 2/6.. Training loss: 1.594.. Validation loss: 0.808.. Validation accuracy: 79.65%
# Epoch 2/6.. Training loss: 2.036.. Validation loss: 0.798.. Validation accuracy: 79.02%
# Epoch 2/6.. Training loss: 1.764.. Validation loss: 0.807.. Validation accuracy: 78.18%
# Epoch 2/6.. Training loss: 1.622.. Validation loss: 0.768.. Validation accuracy: 80.82%
# Epoch 2/6.. Training loss: 1.837.. Validation loss: 0.766.. Validation accuracy: 80.58%
# Epoch 2/6.. Training loss: 1.777.. Validation loss: 0.788.. Validation accuracy: 79.53%
# Epoch 2/6.. Training loss: 1.756.. Validation loss: 0.806.. Validation accuracy: 78.90%
# Epoch 2/6.. Training loss: 1.733.. Validation loss: 0.813.. Validation accuracy: 78.39%
# Epoch 2/6.. Training loss: 2.005.. Validation loss: 0.809.. Validation accuracy: 77.70%
# Epoch 2/6.. Training loss: 2.192.. Validation loss: 0.783.. Validation accuracy: 79.50%
# Epoch 3/6.. Training loss: 1.783.. Validation loss: 0.782.. Validation accuracy: 79.86%
# Epoch 3/6.. Training loss: 1.594.. Validation loss: 0.759.. Validation accuracy: 78.26%
# Epoch 3/6.. Training loss: 1.529.. Validation loss: 0.723.. Validation accuracy: 81.05%
# Epoch 3/6.. Training loss: 1.729.. Validation loss: 0.719.. Validation accuracy: 80.64%
# Epoch 3/6.. Training loss: 1.997.. Validation loss: 0.707.. Validation accuracy: 81.09%
# Epoch 3/6.. Training loss: 1.824.. Validation loss: 0.728.. Validation accuracy: 79.65%
# Epoch 3/6.. Training loss: 1.639.. Validation loss: 0.750.. Validation accuracy: 79.14%
# Epoch 3/6.. Training loss: 1.722.. Validation loss: 0.742.. Validation accuracy: 80.82%
# Epoch 3/6.. Training loss: 1.614.. Validation loss: 0.719.. Validation accuracy: 80.22%
# Epoch 3/6.. Training loss: 1.847.. Validation loss: 0.728.. Validation accuracy: 80.70%
# Epoch 3/6.. Training loss: 1.547.. Validation loss: 0.769.. Validation accuracy: 80.06%
# Epoch 3/6.. Training loss: 1.597.. Validation loss: 0.777.. Validation accuracy: 79.94%
# Epoch 3/6.. Training loss: 1.693.. Validation loss: 0.751.. Validation accuracy: 80.40%
# Epoch 3/6.. Training loss: 1.537.. Validation loss: 0.737.. Validation accuracy: 80.44%
# Epoch 3/6.. Training loss: 1.556.. Validation loss: 0.739.. Validation accuracy: 80.34%
# Epoch 3/6.. Training loss: 1.524.. Validation loss: 0.723.. Validation accuracy: 81.30%
# Epoch 3/6.. Training loss: 1.668.. Validation loss: 0.717.. Validation accuracy: 81.57%
# Epoch 3/6.. Training loss: 1.654.. Validation loss: 0.704.. Validation accuracy: 81.09%
# Epoch 3/6.. Training loss: 1.817.. Validation loss: 0.657.. Validation accuracy: 81.72%
# Epoch 3/6.. Training loss: 1.549.. Validation loss: 0.667.. Validation accuracy: 82.41%
# Epoch 3/6.. Training loss: 1.782.. Validation loss: 0.662.. Validation accuracy: 82.17%
# Epoch 3/6.. Training loss: 1.660.. Validation loss: 0.661.. Validation accuracy: 83.25%
# Epoch 3/6.. Training loss: 1.552.. Validation loss: 0.667.. Validation accuracy: 83.25%
# Epoch 3/6.. Training loss: 1.528.. Validation loss: 0.696.. Validation accuracy: 82.05%
# Epoch 3/6.. Training loss: 1.587.. Validation loss: 0.715.. Validation accuracy: 80.22%
# Epoch 3/6.. Training loss: 1.472.. Validation loss: 0.710.. Validation accuracy: 80.46%
# Epoch 3/6.. Training loss: 1.625.. Validation loss: 0.707.. Validation accuracy: 80.46%
# Epoch 3/6.. Training loss: 1.550.. Validation loss: 0.696.. Validation accuracy: 79.98%
# Epoch 3/6.. Training loss: 1.820.. Validation loss: 0.676.. Validation accuracy: 80.82%
# Epoch 3/6.. Training loss: 2.053.. Validation loss: 0.673.. Validation accuracy: 81.66%
# Epoch 3/6.. Training loss: 1.540.. Validation loss: 0.660.. Validation accuracy: 82.72%
# Epoch 3/6.. Training loss: 1.475.. Validation loss: 0.661.. Validation accuracy: 82.84%
# Epoch 3/6.. Training loss: 1.696.. Validation loss: 0.678.. Validation accuracy: 83.32%
# Epoch 3/6.. Training loss: 1.697.. Validation loss: 0.708.. Validation accuracy: 80.92%
# Epoch 3/6.. Training loss: 2.052.. Validation loss: 0.696.. Validation accuracy: 81.42%
# Epoch 3/6.. Training loss: 1.749.. Validation loss: 0.690.. Validation accuracy: 82.14%
# Epoch 3/6.. Training loss: 1.683.. Validation loss: 0.691.. Validation accuracy: 81.04%
# Epoch 3/6.. Training loss: 1.629.. Validation loss: 0.668.. Validation accuracy: 82.60%
# Epoch 3/6.. Training loss: 1.541.. Validation loss: 0.653.. Validation accuracy: 83.44%
# Epoch 3/6.. Training loss: 1.499.. Validation loss: 0.655.. Validation accuracy: 82.87%
# Epoch 3/6.. Training loss: 1.623.. Validation loss: 0.678.. Validation accuracy: 81.57%
# Epoch 4/6.. Training loss: 1.767.. Validation loss: 0.656.. Validation accuracy: 83.47%
# Epoch 4/6.. Training loss: 1.739.. Validation loss: 0.652.. Validation accuracy: 83.11%
# Epoch 4/6.. Training loss: 1.577.. Validation loss: 0.677.. Validation accuracy: 81.42%
# Epoch 4/6.. Training loss: 1.574.. Validation loss: 0.707.. Validation accuracy: 80.97%
# Epoch 4/6.. Training loss: 1.757.. Validation loss: 0.660.. Validation accuracy: 82.75%
# Epoch 4/6.. Training loss: 1.846.. Validation loss: 0.652.. Validation accuracy: 82.41%
# Epoch 4/6.. Training loss: 1.716.. Validation loss: 0.680.. Validation accuracy: 81.09%
# Epoch 4/6.. Training loss: 1.627.. Validation loss: 0.702.. Validation accuracy: 79.07%
# Epoch 4/6.. Training loss: 1.788.. Validation loss: 0.661.. Validation accuracy: 82.26%
# Epoch 4/6.. Training loss: 1.522.. Validation loss: 0.655.. Validation accuracy: 82.63%
# Epoch 4/6.. Training loss: 1.104.. Validation loss: 0.693.. Validation accuracy: 82.51%
# Epoch 4/6.. Training loss: 1.676.. Validation loss: 0.687.. Validation accuracy: 82.87%
# Epoch 4/6.. Training loss: 1.366.. Validation loss: 0.662.. Validation accuracy: 82.39%
# Epoch 4/6.. Training loss: 1.422.. Validation loss: 0.641.. Validation accuracy: 82.17%
# Epoch 4/6.. Training loss: 1.624.. Validation loss: 0.648.. Validation accuracy: 82.17%
# Epoch 4/6.. Training loss: 1.712.. Validation loss: 0.624.. Validation accuracy: 83.37%
# Epoch 4/6.. Training loss: 1.674.. Validation loss: 0.604.. Validation accuracy: 83.73%
# Epoch 4/6.. Training loss: 1.537.. Validation loss: 0.600.. Validation accuracy: 83.97%
# Epoch 4/6.. Training loss: 1.469.. Validation loss: 0.636.. Validation accuracy: 83.61%
# Epoch 4/6.. Training loss: 1.801.. Validation loss: 0.686.. Validation accuracy: 81.69%
# Epoch 4/6.. Training loss: 1.523.. Validation loss: 0.733.. Validation accuracy: 80.13%
# Epoch 4/6.. Training loss: 1.452.. Validation loss: 0.759.. Validation accuracy: 79.23%
# Epoch 4/6.. Training loss: 1.539.. Validation loss: 0.736.. Validation accuracy: 79.23%
# Epoch 4/6.. Training loss: 1.700.. Validation loss: 0.736.. Validation accuracy: 80.56%
# Epoch 4/6.. Training loss: 1.696.. Validation loss: 0.675.. Validation accuracy: 82.12%
# Epoch 4/6.. Training loss: 1.546.. Validation loss: 0.655.. Validation accuracy: 83.44%
# Epoch 4/6.. Training loss: 1.843.. Validation loss: 0.622.. Validation accuracy: 85.00%
# Epoch 4/6.. Training loss: 1.288.. Validation loss: 0.650.. Validation accuracy: 84.19%
# Epoch 4/6.. Training loss: 1.674.. Validation loss: 0.691.. Validation accuracy: 82.17%
# Epoch 4/6.. Training loss: 1.683.. Validation loss: 0.732.. Validation accuracy: 80.13%
# Epoch 4/6.. Training loss: 1.627.. Validation loss: 0.740.. Validation accuracy: 80.94%
# Epoch 4/6.. Training loss: 1.534.. Validation loss: 0.767.. Validation accuracy: 78.81%
# Epoch 4/6.. Training loss: 1.771.. Validation loss: 0.710.. Validation accuracy: 80.13%
# Epoch 4/6.. Training loss: 1.503.. Validation loss: 0.665.. Validation accuracy: 81.36%
# Epoch 4/6.. Training loss: 1.679.. Validation loss: 0.674.. Validation accuracy: 80.64%
# Epoch 4/6.. Training loss: 1.578.. Validation loss: 0.660.. Validation accuracy: 81.93%
# Epoch 4/6.. Training loss: 1.564.. Validation loss: 0.653.. Validation accuracy: 82.29%
# Epoch 4/6.. Training loss: 1.253.. Validation loss: 0.651.. Validation accuracy: 81.33%
# Epoch 4/6.. Training loss: 1.321.. Validation loss: 0.642.. Validation accuracy: 82.17%
# Epoch 4/6.. Training loss: 1.504.. Validation loss: 0.635.. Validation accuracy: 82.39%
# Epoch 4/6.. Training loss: 1.565.. Validation loss: 0.636.. Validation accuracy: 82.96%
# Epoch 5/6.. Training loss: 1.534.. Validation loss: 0.650.. Validation accuracy: 83.20%
# Epoch 5/6.. Training loss: 1.806.. Validation loss: 0.647.. Validation accuracy: 83.59%
# Epoch 5/6.. Training loss: 1.446.. Validation loss: 0.678.. Validation accuracy: 82.80%
# Epoch 5/6.. Training loss: 1.430.. Validation loss: 0.691.. Validation accuracy: 80.78%
# Epoch 5/6.. Training loss: 1.624.. Validation loss: 0.665.. Validation accuracy: 80.54%
# Epoch 5/6.. Training loss: 1.516.. Validation loss: 0.652.. Validation accuracy: 82.53%
# Epoch 5/6.. Training loss: 1.394.. Validation loss: 0.632.. Validation accuracy: 82.51%
# Epoch 5/6.. Training loss: 1.293.. Validation loss: 0.598.. Validation accuracy: 84.07%
# Epoch 5/6.. Training loss: 1.489.. Validation loss: 0.586.. Validation accuracy: 84.43%
# Epoch 5/6.. Training loss: 1.568.. Validation loss: 0.588.. Validation accuracy: 83.25%
# Epoch 5/6.. Training loss: 1.451.. Validation loss: 0.589.. Validation accuracy: 83.83%
# Epoch 5/6.. Training loss: 1.209.. Validation loss: 0.594.. Validation accuracy: 84.67%
# Epoch 5/6.. Training loss: 1.530.. Validation loss: 0.613.. Validation accuracy: 82.99%
# Epoch 5/6.. Training loss: 1.530.. Validation loss: 0.596.. Validation accuracy: 84.19%
# Epoch 5/6.. Training loss: 1.383.. Validation loss: 0.567.. Validation accuracy: 84.55%
# Epoch 5/6.. Training loss: 1.601.. Validation loss: 0.577.. Validation accuracy: 84.21%
# Epoch 5/6.. Training loss: 1.657.. Validation loss: 0.567.. Validation accuracy: 83.83%
# Epoch 5/6.. Training loss: 1.691.. Validation loss: 0.574.. Validation accuracy: 83.47%
# Epoch 5/6.. Training loss: 1.728.. Validation loss: 0.548.. Validation accuracy: 84.55%
# Epoch 5/6.. Training loss: 1.485.. Validation loss: 0.534.. Validation accuracy: 85.03%
# Epoch 5/6.. Training loss: 1.531.. Validation loss: 0.558.. Validation accuracy: 83.61%
# Epoch 5/6.. Training loss: 1.603.. Validation loss: 0.593.. Validation accuracy: 83.97%
# Epoch 5/6.. Training loss: 1.808.. Validation loss: 0.613.. Validation accuracy: 83.59%
# Epoch 5/6.. Training loss: 1.539.. Validation loss: 0.603.. Validation accuracy: 83.92%
# Epoch 5/6.. Training loss: 1.832.. Validation loss: 0.581.. Validation accuracy: 83.68%
# Epoch 5/6.. Training loss: 1.467.. Validation loss: 0.565.. Validation accuracy: 85.36%
# Epoch 5/6.. Training loss: 1.691.. Validation loss: 0.575.. Validation accuracy: 83.08%
# Epoch 5/6.. Training loss: 1.504.. Validation loss: 0.598.. Validation accuracy: 84.07%
# Epoch 5/6.. Training loss: 1.650.. Validation loss: 0.566.. Validation accuracy: 83.80%
# Epoch 5/6.. Training loss: 1.506.. Validation loss: 0.557.. Validation accuracy: 84.16%
# Epoch 5/6.. Training loss: 1.693.. Validation loss: 0.572.. Validation accuracy: 83.44%
# Epoch 5/6.. Training loss: 1.477.. Validation loss: 0.587.. Validation accuracy: 82.96%
# Epoch 5/6.. Training loss: 1.558.. Validation loss: 0.557.. Validation accuracy: 83.92%
# Epoch 5/6.. Training loss: 1.401.. Validation loss: 0.543.. Validation accuracy: 85.00%
# Epoch 5/6.. Training loss: 1.553.. Validation loss: 0.567.. Validation accuracy: 84.88%
# Epoch 5/6.. Training loss: 1.677.. Validation loss: 0.605.. Validation accuracy: 84.04%
# Epoch 5/6.. Training loss: 1.610.. Validation loss: 0.616.. Validation accuracy: 83.08%
# Epoch 5/6.. Training loss: 1.805.. Validation loss: 0.604.. Validation accuracy: 84.04%
# Epoch 5/6.. Training loss: 1.468.. Validation loss: 0.570.. Validation accuracy: 84.16%
# Epoch 5/6.. Training loss: 1.608.. Validation loss: 0.581.. Validation accuracy: 84.16%
# Epoch 5/6.. Training loss: 1.448.. Validation loss: 0.584.. Validation accuracy: 84.40%
# Epoch 6/6.. Training loss: 1.469.. Validation loss: 0.575.. Validation accuracy: 84.40%
# Epoch 6/6.. Training loss: 1.461.. Validation loss: 0.587.. Validation accuracy: 83.44%
# Epoch 6/6.. Training loss: 1.344.. Validation loss: 0.570.. Validation accuracy: 83.92%
# Epoch 6/6.. Training loss: 1.399.. Validation loss: 0.565.. Validation accuracy: 84.88%
# Epoch 6/6.. Training loss: 1.357.. Validation loss: 0.595.. Validation accuracy: 85.00%
# Epoch 6/6.. Training loss: 1.562.. Validation loss: 0.632.. Validation accuracy: 83.68%
# Epoch 6/6.. Training loss: 1.438.. Validation loss: 0.651.. Validation accuracy: 83.20%
# Epoch 6/6.. Training loss: 1.422.. Validation loss: 0.663.. Validation accuracy: 83.47%
# Epoch 6/6.. Training loss: 1.612.. Validation loss: 0.640.. Validation accuracy: 82.87%
# Epoch 6/6.. Training loss: 1.484.. Validation loss: 0.640.. Validation accuracy: 84.28%
# Epoch 6/6.. Training loss: 1.136.. Validation loss: 0.654.. Validation accuracy: 83.20%
# Epoch 6/6.. Training loss: 1.618.. Validation loss: 0.583.. Validation accuracy: 84.64%
# Epoch 6/6.. Training loss: 1.125.. Validation loss: 0.526.. Validation accuracy: 86.08%
# Epoch 6/6.. Training loss: 1.432.. Validation loss: 0.524.. Validation accuracy: 85.84%
# Epoch 6/6.. Training loss: 1.511.. Validation loss: 0.529.. Validation accuracy: 85.60%
# Epoch 6/6.. Training loss: 1.446.. Validation loss: 0.559.. Validation accuracy: 85.00%
# Epoch 6/6.. Training loss: 1.319.. Validation loss: 0.572.. Validation accuracy: 83.44%
# Epoch 6/6.. Training loss: 1.402.. Validation loss: 0.580.. Validation accuracy: 83.11%
# Epoch 6/6.. Training loss: 1.819.. Validation loss: 0.573.. Validation accuracy: 84.88%
# Epoch 6/6.. Training loss: 1.353.. Validation loss: 0.560.. Validation accuracy: 84.52%
# Epoch 6/6.. Training loss: 1.482.. Validation loss: 0.557.. Validation accuracy: 85.12%
# Epoch 6/6.. Training loss: 1.513.. Validation loss: 0.563.. Validation accuracy: 84.64%
# Epoch 6/6.. Training loss: 1.424.. Validation loss: 0.528.. Validation accuracy: 85.94%
# Epoch 6/6.. Training loss: 1.558.. Validation loss: 0.515.. Validation accuracy: 85.96%
# Epoch 6/6.. Training loss: 1.520.. Validation loss: 0.534.. Validation accuracy: 86.44%
# Epoch 6/6.. Training loss: 1.243.. Validation loss: 0.563.. Validation accuracy: 85.63%
# Epoch 6/6.. Training loss: 1.288.. Validation loss: 0.583.. Validation accuracy: 85.51%
# Epoch 6/6.. Training loss: 1.698.. Validation loss: 0.570.. Validation accuracy: 85.75%
# Epoch 6/6.. Training loss: 1.546.. Validation loss: 0.542.. Validation accuracy: 85.99%
# Epoch 6/6.. Training loss: 1.405.. Validation loss: 0.540.. Validation accuracy: 85.42%
# Epoch 6/6.. Training loss: 1.510.. Validation loss: 0.552.. Validation accuracy: 84.82%
# Epoch 6/6.. Training loss: 1.379.. Validation loss: 0.562.. Validation accuracy: 84.31%
# Epoch 6/6.. Training loss: 1.390.. Validation loss: 0.576.. Validation accuracy: 84.79%
# Epoch 6/6.. Training loss: 1.377.. Validation loss: 0.608.. Validation accuracy: 83.32%
# Epoch 6/6.. Training loss: 1.685.. Validation loss: 0.575.. Validation accuracy: 83.95%
# Epoch 6/6.. Training loss: 1.476.. Validation loss: 0.540.. Validation accuracy: 85.03%
# Epoch 6/6.. Training loss: 1.248.. Validation loss: 0.535.. Validation accuracy: 86.11%
# Epoch 6/6.. Training loss: 1.234.. Validation loss: 0.535.. Validation accuracy: 86.38%
# Epoch 6/6.. Training loss: 1.438.. Validation loss: 0.552.. Validation accuracy: 85.66%
# Epoch 6/6.. Training loss: 1.503.. Validation loss: 0.538.. Validation accuracy: 85.08%
# Epoch 6/6.. Training loss: 1.493.. Validation loss: 0.530.. Validation accuracy: 85.92%

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Function Test Network and print accuracy - Arguments include the model
def test_network(model, data_loader):
    accuracy = 0
    model.eval() #Turns off model inference mode

    #Turn off gradients for testing
    with torch.no_grad():

        # Calculate accuracy and loss
        for images, labels in data_loader: #Get images and labels from test data to do validation
            images, labels = images.to(device), labels.to(device) #set to device
            output_logps = model.forward(images)  # get log probability from test set
            probability = torch.exp(output_logps) #logps = returning softmax - log probability of classes
            top_p, top_class = probability.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape) #compares class to labels
            accuracy += equals.type(torch.FloatTensor).mean()

        print( f"Test accuracy: {accuracy/len(data_loader):.3f}") #average accuracy - summing up accuracy for each batch / total number of batches
        model.train() #set model back into training mode

# %%
#Run Function to test model accuracy using Test Data
test_network(model, testloader)

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
#Save the checkpoint
def save_checkpoint(train_data, model, optimiser, path='checkpoint.pth', arch='vgg19', inputs=25088, hidden=1096, outputs=102, epochs=6):
    model.class_to_idx = train_data.class_to_idx
    checkpoint = {'arch': arch,
                  'hidden': hidden,
                  'inputs': inputs,
                  'outputs': outputs,
                  'state_dict': model.state_dict(),
                  'class_to_idx': model.class_to_idx,
                  'optimiser_state': optimiser.state_dict(),
                  'epochs': epochs}
    torch.save(checkpoint, path)


save_checkpoint(train_data, model, optimiser, path='checkpoint.pth', arch='vgg19', inputs=25088, hidden=1096, outputs=102, epochs=6)

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Function that loads a checkpoint and rebuilds the model - returns model, optimiser and also epochs

def load_checkpoint(filepath):
    criterion = nn.NLLLoss()
    checkpoint = torch.load(filepath)

    #Load Model with checkpoints
    model = models.vgg19(pretrained=True)
    model.classifier=classifier(model, checkpoint['inputs'], checkpoint['hidden'], checkpoint['outputs'])
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])

    #Load Optimiser
    optimiser = optim.Adam(model.classifier.parameters(), lr=0.03)
    optimiser.load_state_dict(checkpoint['optimiser_state'])

    epochs= checkpoint['epochs']

    return model, optimiser, epochs

# Reload model from checkpoint.pth file
model, optimiser, epochs = load_checkpoint('checkpoint.pth')
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=4096, bias=True)
#     (relu1): ReLU()
#     (dropout): Dropout(p=0.5)
#     (fc2): Linear(in_features=4096, out_features=1000, bias=True)
#     (relu2): ReLU()
#     (fc3): Linear(in_features=1000, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
# Optional - Reload to train network using epochs from checkpoint
train_network(epochs, 5):

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
#Function to process image
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    # TODO: Process a PIL image for use in a PyTorch model
    img = Image.open(image)

    img_transform = transforms.Compose([transforms.Resize(256),
                                         transforms.CenterCrop(224),
                                         transforms.ToTensor(),
                                         transforms.Normalize([0.485, 0.456, 0.406],
                                                              [0.229, 0.224, 0.225])])



    # Transforms image
    image_process =  img_transform(img)

    return image_process

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()

    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)

    ax.imshow(image)

    return ax

imshow(process_image("flowers/test/12/image_03994.jpg"))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # TODO: Implement the code to predict the class from an image file
    with torch.no_grad():    # Turn off gradients
        device = torch.device('cuda' if torch.cuda.is_available() and device=='gpu' else 'cpu')
        model.eval()
        model.to(device) #set model to device

        # Run function to process image
        image = process_image(image_path)
        image = image.unsqueeze_(0)

        image.to(device) #set image to device

        output_logps = model.forward(image)  # Forward pass - get log probability
        probability = torch.exp(output_logps) # Probability
        top_p, top_class = probability.topk(topk, dim=1)

        #Convert tensors to numpy array
        top_p=top_p.numpy()
        top_class=top_class.numpy()

        # store class_to_idx values from modelin a dictionary
        idx_to_class = {model.class_to_idx[i]: i for i in model.class_to_idx}
        classes = [idx_to_class[i] for i in top_class[0]] # Iterate get top classes
        probs = top_p[0] # get Probabilities

        return probs, classes

# %%
# Run predict function and return probs and classes
image_path = 'flowers/test/16/image_06670.jpg'
top_k = 5
probs, classes= predict(image_path, model, top_k)
print(probs)
print(classes)
# Out:
# [ 0.0119453   0.01107642  0.01103215  0.01080994  0.01079387]
# ['92', '16', '13', '93', '23']

# %% [markdown]
# # Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='https://github.com/mlew-udacity/ImageClassifierProject/blob/main/assets/inference_example.png?raw=1' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# Function: Display an image along with the top classes
def display_predict(image_path, model, topk=5):

    #Based on image get probability of image
    probs, classes= predict(image_path, model, topk)

    #Get labels for top 5 - classes returned from predict function
    labels=[cat_to_name[i] for i in classes]

    # Plot flower and assign title
    image = Image.open(image_path)

    plt.figure(figsize = [5,10])
    img = plt.subplot(2,1,1)
    img.set_title(labels[0])
    img.imshow(image)

    # Plot probabilities bar graph
    plt.figure(figsize = [5,10])
    bar = plt.subplot(2,1,2)
    bar.set_yticks(np.arange(5)[::-1])
    bar.set_yticklabels(labels)
    bar.set_title("Predictions")
    bar.barh(np.arange(5)[::-1],probs)
    plt.show() # shows bar graph

# %%
# Run check function with top 5 classes for image defined below
image_path = "flowers/test/37/image_03734.jpg"
display_predict(image_path, model, topk=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-97476f4ac205> in <module>()
#       1 # Run check function with top 5 classes for image defined below
#       2 image_path = "flowers/test/37/image_03734.jpg"
# ----> 3 check(image_path, model, topk=5)
#
# NameError: name 'check' is not defined

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7fcf4273bd03> in <module>()
# ----> 1 nvcc --version
#
# NameError: name 'nvcc' is not defined
